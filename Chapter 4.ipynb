# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\Piyush\Desktop\Pandas\Dataset\adult.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.tail()
# Out:
#        age     workclass  fnlwgt   education  educational-num  \
# 48837   27       Private  257302  Assoc-acdm               12
# 48838   40       Private  154374     HS-grad                9
# 48839   58       Private  151910     HS-grad                9
# 48840   22       Private  201490     HS-grad                9
# 48841   52  Self-emp-inc  287927     HS-grad                9
#
#            marital-status         occupation relationship   race  gender  \
# 48837  Married-civ-spouse       Tech-support         Wife  White  Female
# 48838  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 48839             Widowed       Adm-clerical    Unmarried  White  Female
# 48840       Never-married       Adm-clerical    Own-child  White    Male
# 48841  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country income
# 48837             0             0              38  United-States  <=50K
# ...

# %%
df.shape
# Out:
# (48842, 15)

# %%
print("Number of rows:",df.shape[0])
print("Number of columns:",df.shape[1])
# Out:
# Number of rows: 48842
# Number of columns: 15

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %% [markdown]
# FETCH RANDOM SAMPLES FROM DATASET(50%)

# %%
df.sample(frac=0.50)                #for getting 50% data by random sample.... it gives everytime  random output
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 7681    28    Private  122037     Bachelors               13
# 14155   22    Private  186365  Some-college               10
# 4286    58    Private   95428       Masters               14
# 10377   28    Private  302406   Prof-school               15
# 36422   26    Private  306513  Some-college               10
# ...    ...        ...     ...           ...              ...
# 16561   22    Private   34918     Bachelors               13
# 47113   43  Local-gov  188280       Masters               14
# 16519   38  Local-gov  115076       Masters               14
# 48504   31    Private  181372       HS-grad                9
# 36522   65  State-gov  215908       HS-grad                9
#
#            marital-status         occupation   relationship   race  gender  \
# 7681   Married-civ-spouse     Prof-specialty        Husband  White    Male
# 14155       Never-married  Machine-op-inspct  Not-in-family  White    Male
# ...

# %%
df.sample(frac=0.50,random_state=100)      #by using random_state=100,111....etc. we can get everytime SAME Output
# Out:
#        age  workclass  fnlwgt     education  educational-num  \
# 12393   37    Private  110331   Prof-school               15
# 48701   23    Private   45834     Bachelors               13
# 17918   28    Private   89718       HS-grad                9
# 11352   30    Private  351770           9th                5
# 36198   31    Private  164190          10th                6
# ...    ...        ...     ...           ...              ...
# 48573   41    Private  318046  Some-college               10
# 47252   41  Local-gov   33658  Some-college               10
# 33142   69    Private  312653  Some-college               10
# 2965    21          ?  334593  Some-college               10
# 32089   34    Private  186269       HS-grad                9
#
#            marital-status        occupation   relationship   race  gender  \
# 12393  Married-civ-spouse     Other-service           Wife  White  Female
# 48701       Never-married   Exec-managerial  Not-in-family  White  Female
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Replace ? with Nan

# %%
df.tail(20)
# Out:
#        age         workclass  fnlwgt     education  educational-num  \
# 48822   41                 ?  202822       HS-grad                9
# 48823   72                 ?  129912       HS-grad                9
# 48824   45         Local-gov  119199    Assoc-acdm               12
# 48825   31           Private  199655       Masters               14
# 48826   39         Local-gov  111499    Assoc-acdm               12
# 48827   37           Private  198216    Assoc-acdm               12
# 48828   43           Private  260761       HS-grad                9
# 48829   65  Self-emp-not-inc   99359   Prof-school               15
# 48830   43         State-gov  255835  Some-college               10
# 48831   43  Self-emp-not-inc   27242  Some-college               10
# 48832   32           Private   34066          10th                6
# 48833   43           Private   84661     Assoc-voc               11
# 48834   32           Private  116138       Masters               14
# ...

# %%
#Let's find how many columns have ? mark...

df.isin(['?']).sum()

#So three columns have ? mark... lets replace it...
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df['workclass']=df['workclass'].replace('?',np.nan)
df['occupation']=df['occupation'].replace('?',np.nan)
df['native-country']=df['native-country'].replace('?',np.nan)

# %%
df.isin(['?']).sum()           #Finally we replace it ....
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Drop All Missing Values

# %%
#firstly we have to calculate missing value percentage... then we drop it according to that... so lets's find 

missing_values_per=df.isnull().sum()*100/len(df)
missing_values_per
# Out:
# age                0.000000
# workclass          5.730724
# fnlwgt             0.000000
# education          0.000000
# educational-num    0.000000
# marital-status     0.000000
# occupation         5.751198
# relationship       0.000000
# race               0.000000
# gender             0.000000
# capital-gain       0.000000
# capital-loss       0.000000
# hours-per-week     0.000000
# native-country     1.754637
# income             0.000000
# dtype: float64

# %%
df.dropna(how='any',inplace=True)    #if u want to drop all values then use how='any'
df.shape
# Out:
# (45222, 15)

# %%
# drop(): Removes specific rows or columns based on their index or label.
# dropna(): Removes rows or columns based on the presence of missing values (NaN).

# %% [markdown]
# Check for Duplicate and remove them

# %%
dup=df.duplicated().any()
print("Is there any duplicated value in the data:",dup)
# Out:
# Is there any duplicated value in the data: True

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (45175, 15)

# %% [markdown]
# df.describe(include='all')           #We can drop columns by analysing below table like capital-gain and capital loss has 75% values as a 0

# %%
df=df.drop(['educational-num','capital-gain','capital-loss'],axis=1)

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %% [markdown]
# UNIVARIATE ANALYSIS
#
# Definition: Univariate analysis involves analyzing data for a single variable. The main purpose is to describe the data and find patterns within that single variable.
#
# Techniques:
#
# Summary Statistics: Mean, median, mode, range, variance, standard deviation.
#
# Visualizations: Histogram, box plot, bar chart, pie chart.

# %% [markdown]
# Find the distribution of age

# %%
df['age'].describe()
# Out:
# count    45175.000000
# mean        38.556170
# std         13.215349
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         47.000000
# max         90.000000
# Name: age, dtype: float64

# %%
df['age'].hist()
# Out:
# <Axes: >

# %% [markdown]
# How many people have age between 17 to 48

# %%
len(df[df['age'].between(17,48)])
#sum(df['age'].between(17,48))   by sum
# Out:
# 34858

# %%
df['workclass'].describe()
# Out:
# count       45175
# unique          7
# top       Private
# freq        33262
# Name: workclass, dtype: object

# %%
plt.figure(figsize=(10,10))
df['workclass'].hist()
# Out:
# <Axes: >

# %% [markdown]
# How many persons have bachelors and masters degree

# %%
df.columns
# Out:
# Index(['age', 'workclass', 'fnlwgt', 'education', 'marital-status',
#        'occupation', 'relationship', 'race', 'gender', 'hours-per-week',
#        'native-country', 'income'],
#       dtype='object')

# %%
df.education
# Out:
# 0                11th
# 1             HS-grad
# 2          Assoc-acdm
# 3        Some-college
# 5                10th
#              ...
# 48837      Assoc-acdm
# 48838         HS-grad
# 48839         HS-grad
# 48840         HS-grad
# 48841         HS-grad
# Name: education, Length: 45175, dtype: object

# %%
Degree1=df['education']=='Bachelors'
Degree2=df['education']=='Masters'        #separately

# %%
len(df[Degree1 | Degree2])
# Out:
# 45175

# %%
len(df[df['education'].isin(['Bachelors','Masters'])])     #USING isin()
# Out:
# 45175

# %% [markdown]
# Bivariate Analysis
#
# Definition: Bivariate analysis involves analyzing the relationship between two variables. The goal is to understand the association or correlation between these variables.
#
# Techniques:
#
# Summary Statistics: Correlation coefficient, covariance.
#
# Visualizations: Scatter plot, line plot, heatmap (for correlation matrices), side-by-side box plots.

# %%
sns.boxplot(x='income',y='age',data=df,palette='Set3')
# Out:
# C:\Users\Piyush\AppData\Local\Temp\ipykernel_5772\2114877617.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='income',y='age',data=df,palette='Set3')
# <Axes: xlabel='income', ylabel='age'>

# %%
sns.boxplot(x='income',y='age',hue='gender',data=df,palette='Set3')      #Boxplot between age, gender & salary
# Out:
# <Axes: xlabel='income', ylabel='age'>

# %%
# def income_data(sal):
#     if sal=='<=50K':
#         return 0
#     else:
#         return 1

# df['encoded_income']=df['income'].apply(income_data)
# df

# %%
df.drop(['income_num','encoded_income','income'],axis=1)
# Out:
#        age     workclass  fnlwgt  education      marital-status  \
# 0       25       Private  226802  Bachelors       Never-married
# 1       38       Private   89814  Bachelors  Married-civ-spouse
# 2       28     Local-gov  336951  Bachelors  Married-civ-spouse
# 3       44       Private  160323  Bachelors  Married-civ-spouse
# 5       34       Private  198693  Bachelors       Never-married
# ...    ...           ...     ...        ...                 ...
# 48837   27       Private  257302  Bachelors  Married-civ-spouse
# 48838   40       Private  154374  Bachelors  Married-civ-spouse
# 48839   58       Private  151910  Bachelors             Widowed
# 48840   22       Private  201490  Bachelors       Never-married
# 48841   52  Self-emp-inc  287927  Bachelors  Married-civ-spouse
#
#               occupation   relationship   race  gender  hours-per-week  \
# 0      Machine-op-inspct      Own-child  Black    Male              40
# ...

# %%
df['workclass']=df['workclass'].astype('category')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45175 entries, 0 to 48841
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             45175 non-null  int64
#  1   workclass       45175 non-null  category
#  2   fnlwgt          45175 non-null  int64
#  3   education       45175 non-null  object
#  4   marital-status  45175 non-null  object
#  5   occupation      45175 non-null  object
#  6   relationship    45175 non-null  object
#  7   race            45175 non-null  object
#  8   gender          45175 non-null  object
#  9   hours-per-week  45175 non-null  int64
#  10  native-country  45175 non-null  object
#  11  income_num      45175 non-null  float64
#  12  encoded_income  45175 non-null  int64
#  13  income          0 non-null      float64
# dtypes: category(1), float64(2), int64(4), object(7)
# memory usage: 4.9+ MB
